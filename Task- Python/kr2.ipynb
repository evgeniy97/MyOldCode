# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy.interpolate
# %matplotlib inline

# %%
buf = plt.imread("365847.png")
plt.imshow(buf)
buf.shape
# Out:
# (512, 512, 3)

# %%
cmaps = [matplotlib.colors.LinearSegmentedColormap.from_list('',['#000000','#FF0000']), # RED
         matplotlib.colors.LinearSegmentedColormap.from_list('',['#000000','#00FF00']), # Green
         matplotlib.colors.LinearSegmentedColormap.from_list('',['#000000','#0000FF']), # Blue
         matplotlib.colors.LinearSegmentedColormap.from_list('',['#000000','#FFFFFF'])] # White

# %%
fig, ax = plt.subplots(1,3, figsize=(20,20))
for i, a in enumerate(ax):
    a.imshow(buf[:,:,i],cmap = cmaps[i])

# %%
b11 = buf[0:256, 0:256,1]
b21 = buf[256:512,0:256,1]
b12 = buf[0:256,256:512,1]
b22 = buf[256:512,256:512,1]

c11 = buf[0:256, 0:256,2]
c21 = buf[256:512,0:256,2]
c12 = buf[0:256,256:512,2]
c22 = buf[256:512,256:512,2]

# %%
plt.imshow(b11)

# %%
plt.imshow(c11)

# %%
plt.imshow(np.flip(с11,0))

# %%
a11 = b11 + np.flip(с11,0)
plt.imshow(a11)

# %%
plt.imshow(b12)

# %%
plt.imshow(c21)

# %%
plt.imshow(np.flip(c21,1))

# %%
a12 = 1 - (b12 - np.flip(c21,1))
plt.imshow(a12)

# %%
plt.imshow(b21)

# %%
plt.imshow(c12)

# %%
plt.imshow(np.flip(np.rot90(c12,1),1))

# %%
a21 = 1 -(b21 - np.flip(np.rot90(c12,1),1))
plt.imshow(a21)

# %%
plt.imshow(b22)

# %%
plt.imshow(с22)

# %%
plt.imshow(np.flip(с22,1))

# %%
a22 = b22 + np.flip(с22,1)
plt.imshow(a22)

# %%
a1 = np.hstack((np.flip(a12,1),np.flip(a22,1)))
plt.imshow(a1)

# %%
a2 = np.hstack((np.flip(a11,0),np.flip(np.rot90(a21,1),1)))
plt.imshow(a2)

# %%
a = np.vstack((a2,a1))
plt.imshow(a)
